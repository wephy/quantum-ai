# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets as ds
import scienceplots

plt.style.use(["science"])

# %%
n_samples=1000
noise=0.1
random_state=42

datasets = {
    "moons": ds.make_moons(n_samples=n_samples, noise=noise, random_state=random_state),
    "circles": ds.make_circles(n_samples=n_samples, noise=noise, factor=0.5, random_state=random_state),
}

# %%
plt.figure(figsize=(16, 5))

for i, (dataset_name, (X, z)) in enumerate(datasets.items()):
    plt.subplot(1, 3, i+1)
    sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=z, s=40, alpha=0.7, edgecolor=None)
    plt.title(dataset_name)

plt.show()
